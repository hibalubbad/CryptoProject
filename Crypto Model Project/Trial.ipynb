# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Importing Data

# %%
data=pd.read_csv("/Ethereum Historical Data .csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-14a4da0e56df> in <module>()
# ----> 1 data=pd.read_csv("/Ethereum Historical Data .csv")
#       2 data.shape()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
data.head()
# Out:
#            Date     Price      Open      High       Low     Vol. Change %
# 0  Mar 17, 2021  1,776.14  1,804.56  1,811.93  1,773.75    1.69M   -1.59%
# 1  Mar 16, 2021  1,804.85  1,792.08  1,817.35  1,715.97    1.81M    0.70%
# 2  Mar 15, 2021  1,792.38  1,848.18  1,890.59  1,745.04    1.70M   -3.07%
# 3  Mar 14, 2021  1,849.06  1,921.29  1,932.36  1,836.78  671.56K   -3.75%
# 4  Mar 13, 2021  1,921.13  1,767.05  1,943.36  1,730.46    1.79M    8.73%

# %%
date = data['Date']

# %%
print("\n\nDatatypes of features: \n",'-' * 20,"\n", data.dtypes)
# Out:
# Datatypes of features:
#  --------------------
#  Date        object
# Price       object
# Open        object
# High        object
# Low         object
# Vol.        object
# Change %    object
# dtype: object

# %%
data["Price"] = [float(str(i).replace(",", "")) for i in data["Price"]]
data['Price'].astype(str).astype(float)
data['Open'] = [float(str(i).replace(",", "")) for i in data['Open']]
data['Open'].astype(str).astype(float)
data['High'] = [float(str(i).replace(",", "")) for i in data['High']]
data['High'].astype(str).astype(float)
data['Low'] = [float(str(i).replace(",", "")) for i in data['Low']]
data['Low'].astype(str).astype(float)
# data['Change %'] = [float(str(i).replace(",", "")) for i in data['Change %']]
# data['Change %'].astype(str).astype(float)


# data['Low'].astype(str).astype(float)
# data['Change %'].astype(str).astype(float)
# Out:
# 0     1773.75
# 1     1715.97
# 2     1745.04
# 3     1836.78
# 4     1730.46
# 5     1723.18
# 6     1729.05
# 7     1759.50
# 8     1801.29
# 9     1665.54
# 10    1634.73
# 11    1514.62
# 12    1443.32
# 13    1506.86
# 14    1477.72
# 15    1457.22
# 16    1411.55
# 17    1294.79
# 18    1427.15
# 19    1403.30
# 20    1460.92
# 21    1505.79
# 22    1370.45
# 23    1561.68
# 24    1885.70
# 25    1800.00
# 26    1892.70
# 27    1849.05
# 28    1734.15
# Name: Low, dtype: float64

# %%
date.head()
# Out:
# 0    Mar 17, 2021
# 1    Mar 16, 2021
# 2    Mar 15, 2021
# 3    Mar 14, 2021
# 4    Mar 13, 2021
# Name: Date, dtype: object

# %%
newData = data.drop(['Vol.'] , axis=1)
newData = newData.drop(['Date'] , axis=1)
newData = newData.drop(['Change %'] , axis=1)
newData = newData.drop(['Open'] , axis=1)

# %%
plt.plot(newData)
